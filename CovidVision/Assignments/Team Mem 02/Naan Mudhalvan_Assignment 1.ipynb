# %% [markdown]
# NAME : SRIRAM R
# ROLL NO : 2020115092
# COLLEGE : COLLEGE OF ENGINEERING, GUINDY
# GROUP : GROUP 1
# TRACK : ARTIFICIAL INTELLIGENCE

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import skew
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter as co
from math import floor
from sklearn.model_selection import train_test_split

# %% [markdown]
# # LOADING DATASET

# %%
df = pd.read_csv("House Price India.csv")
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
colname="Price"
print("Mean ",np.mean(df[colname]))
print("Median ",np.median(df[colname]))
print("Mode ",stats.mode(df[colname]))
print("Standard deviation ",np.std(df[colname]))
print("Variance ",np.var(df[colname]))
print("Skewness ",skew(df[colname]))
print("Kurtosis ",stats.kurtosis(df[colname]))
# Out:
# Mean  538932.2183310534
# Median  450000.0
# Mode  ModeResult(mode=array([450000], dtype=int64), count=array([114]))
# Standard deviation  367519.81108215527
# Variance  135070811537.86308
# Skewness  4.268859681780932
# Kurtosis  40.307719119751845

# %%
sns.displot(df[colname])

# %%
sns.distplot(df[colname][:100],hist=False)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
plt.boxplot(df['Date'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dddb021b80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dddb02e160>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dddb0218b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dddb02e700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dddb02e9d0>],
#  'means': []}

# %%
plt.hist(df[colname][:100])
# Out:
# (array([38., 25., 26.,  5.,  1.,  3.,  0.,  0.,  0.,  2.]),
#  array([ 235000.,  449500.,  664000.,  878500., 1093000., 1307500.,
#         1522000., 1736500., 1951000., 2165500., 2380000.]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x="number of bathrooms",data=df,palette="Set1")
# Out:
# <AxesSubplot:xlabel='number of bathrooms', ylabel='count'>

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
sns.scatterplot(data=df,x='lot area',y='Price')
# Out:
# <AxesSubplot:xlabel='lot area', ylabel='Price'>

# %%
sns.countplot(data=df[:10],x='Price',hue='Number of schools nearby')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='count'>

# %%
plt.bar(df['number of bedrooms'][:70],df['condition of the house'][:70])
# Out:
# <BarContainer object of 70 artists>

# %%
plt.figure(figsize=(10,5))
plt.violinplot([df['lot area'][:10],df['Price'][:100]],showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1dddb3941c0>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1dddb3940a0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1dddb394c70>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1dddb3a20a0>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x1dddb3a2490>}

# %% [markdown]
# # MULTIVARIATE ANALYSIS

# %%
sns.pairplot(df[['number of bedrooms','living area','number of bathrooms','lot area','Price']][:100])

# %%
fig, ax = plt.subplots(figsize=(20,15)) 
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
ax = df[['number of bedrooms','living area','number of floors','Built Year']][:20].plot()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df[['number of bedrooms','living area','number of floors','lot area','Built Year','Price']],figsize  = [15, 10])
plt.show()

# %% [markdown]
# # DESCRIPTIVE ANALYSIS

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.isna().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
ndf=df[df['Renovation Year']!=0]
val=int((ndf['Renovation Year']-ndf['Built Year']).mean())
val
# Out:
# 56

# %%
df.loc[df['Renovation Year']==0,'Renovation Year']=df['Built Year']+val
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...
