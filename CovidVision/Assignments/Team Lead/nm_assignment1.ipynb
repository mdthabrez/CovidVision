# %% [markdown]
# # Naan Mudhalvan - Assignment - 1
# Name: Kanivan S
# College : College of Engineering Guindy
# Course : Artificial intelligence

# %% [markdown]
# import numpy as np
# import pandas as pd
# import seaborn as sns
# from scipy import stats
# import matplotlib.pyplot as plt
# from scipy.stats import skew
# from sklearn.model_selection import train_test_split

# %% [markdown]
# # Loading Dataset

# %%
df=pd.read_csv("dataset.csv")
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %% [markdown]
# # Univariate analysis

# %%
#Mean
colname="lot area"
print("Mean ",np.mean(df[colname]))
print("Median ",np.median(df[colname]))
print("Mode ",stats.mode(df[colname],keepdims=True))
print("Standar deviation ",np.std(df[colname]))
print("Variance ",np.var(df[colname]))
print("Skewness ",skew(df[colname]))
print("Kurtosis ",stats.kurtosis(df[colname]))
# Out:
# Mean  15093.281121751026
# Median  7620.0
# Mode  ModeResult(mode=array([5000]), count=array([269]))
# Standar deviation  37918.32444072896
# Variance  1437799328.3923833
# Skewness  10.154164143135088
# Kurtosis  164.70052193894898

# %%
print(skew(df[colname]))
print(stats.kurtosis(df[colname]))
# sns.displot(df[colname])
sns.displot(df[colname])
# Out:
# 10.154164143135088
# 164.70052193894898

# %% [markdown]
# Dist Plot

# %%
sns.distplot(df[colname][:100],hist=False)
# Out:
# /Users/kanivan/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='lot area', ylabel='Density'>

# %% [markdown]
#  Box Plot

# %%
plt.boxplot(df['Date'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa841e0ec40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fa841e0e4c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa841e0ea00>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa841e039a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa841e48670>],
#  'means': []}

# %%
plt.boxplot(df['Built Year'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb16418aa90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb164198070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb16418a7c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb164198610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb1641988e0>],
#  'means': []}

# %% [markdown]
# Histogram

# %%
plt.hist(df[colname][:100])
# Out:
# (array([86.,  8.,  3.,  0.,  2.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1180. ,  31837.2,  62494.4,  93151.6, 123808.8, 154466. ,
#         185123.2, 215780.4, 246437.6, 277094.8, 307752. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Bar Graph

# %%
sns.countplot(x="number of bathrooms",data=df,palette="Set1")
# Out:
# <AxesSubplot:xlabel='number of bathrooms', ylabel='count'>

# %% [markdown]
# # Bivariate Analysis

# %%
import matplotlib.pyplot as plt
plt.scatter(scaled_data[:100,5],res[:100,6],c=df['lot area'][:100],cmap='plasma')

# %%
sns.pointplot(x='Price',y='number of bathrooms',data=df[:10],linestyles = '-')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='number of bathrooms'>

# %%
sns.stripplot(x="Distance from the airport", y="living_area_renov", data=df[:300])
# Out:
# <AxesSubplot:xlabel='Distance from the airport', ylabel='living_area_renov'>

# %%
sns.swarmplot(x="Number of schools nearby", y="Price", data=df[:100])
# Out:
# <AxesSubplot:xlabel='Number of schools nearby', ylabel='Price'>

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df[["number of bedrooms","number of bathrooms","Price","lot area"]],hue="lot area")

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(), annot=True,cmap="plasma")
# Out:
# <AxesSubplot:>

# %%
pd.plotting.scatter_matrix(df.loc[:, "Longitude":"Price"], diagonal="kde",figsize=(20,15))
plt.show()

# %%
from sklearn import decomposition
X = df
y = df['number of bedrooms']
pca = decomposition.PCA(n_components=2) 
X = pca.fit_transform(X)
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
res=df.loc[:,:]
print(res)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...
